# %% [markdown]
# <a href="https://colab.research.google.com/github/OusmaneSoo/HomeWork/blob/master/CheckPointPython01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bienvenue dans le jeu Devinez le nombre!
# Je pense à un nombre entre 1 et 100. Pouvez-vous le deviner ?
# Entrez votre réponse : 50
# Votre réponse est trop élevée. Réessayez.
# Entrez votre réponse : 25
# Votre réponse est trop basse. Réessayez.
# Entrez votre réponse : 37

# Votre réponse est trop élevée. Réessayez.

# Entrez votre réponse : 31

# Félicitations ! Vous avez deviné le nombre correctement

import random

nombre_a_deviner = random.randint(1, 100)

n = input("Bienvenue dans le jeu Devinez le nombre! Je pense à un nombre entre 1 et 100. Pouvez-vous le deviner ? Entrez votre réponse : ")

while int(n) != nombre_a_deviner:
    if int(n) > nombre_a_deviner:
        print("Votre réponse est trop élevée. Réessayez.")
        n = input("Entrez votre réponse : ")
    elif int(n) < nombre_a_deviner:
        print("Votre réponse est trop basse. Réessayez.")
        n = input("Entrez votre réponse : ")

print("Félicitations ! Vous avez deviné le nombre correctement")
# Out:
# Bienvenue dans le jeu Devinez le nombre! Je pense à un nombre entre 1 et 100. Pouvez-vous le deviner ? Entrez votre réponse : 5
# Votre réponse est trop basse. Réessayez.
# Entrez votre réponse : 7
# Votre réponse est trop basse. Réessayez.
# Entrez votre réponse : 12
# Votre réponse est trop basse. Réessayez.
# Entrez votre réponse : 13
# Votre réponse est trop basse. Réessayez.
# Entrez votre réponse : 55
# Votre réponse est trop basse. Réessayez.
# Entrez votre réponse : 77
# Votre réponse est trop basse. Réessayez.
# Entrez votre réponse : 88
# Félicitations ! Vous avez deviné le nombre correctement
